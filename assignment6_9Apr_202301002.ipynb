# %% [markdown]
# <a href="https://colab.research.google.com/github/abhimittal2244/BigDataAnalysis/blob/main/assignment6_9Apr_202301002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
data=pd.read_csv("OnlineRetail.csv")
data1=data[["Quantity","UnitPrice"]]
k=KMeans(n_clusters=4,n_init=10)
k.fit(data1)
plt.scatter(data1["Quantity"],data1["UnitPrice"],c=k.labels_)
plt.show()
